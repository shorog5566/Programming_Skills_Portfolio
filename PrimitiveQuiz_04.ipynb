# %%
answer = input("What is the capital of France? ")

if answer == "Paris":
    print("Correct!")
else:
    print("Wrong answer!")
# Out:
# What is the capital of France?  Paris
# Correct!

# %%
answer = input("What is the capital of France? ")

if answer.lower() == "paris":
    print("Correct!")
else:
    print("Wrong answer!")
# Out:
# What is the capital of France?  Paris
# Correct!
