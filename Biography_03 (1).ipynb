# %%
bio = {
    "name": "Shoroog",
    "hometown": "Riyadh",
    "age": 18
}

print(bio["name"])          # print name
print(bio["hometown"])      # print hometown
print(bio["age"])           # print age
# Out:
# Shoroog
# Riyadh
# 18

# %%
name = input("Enter your name: ")
hometown = input("Enter your hometown: ")
age = int(input("Enter your age: "))

bio = {
    "name": name,    # store name 
    "hometown": hometown,     # store hometown
    "age": age               # store age
}

print(bio["name"])
print(bio["hometown"])
print(bio["age"])          # print all
# Out:
# Enter your name:  Shoroog
# Enter your hometown:  Riyadh
# Enter your age:  18
# Shoroog
# Riyadh
# 18
